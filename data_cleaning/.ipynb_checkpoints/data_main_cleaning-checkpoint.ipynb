# %%
import pandas as pd

# %%
# df=pd.read_csv(r'data_main.csv')

# %%
# df.to_excel('data_m.xlsx', index=False)

# %%
data=pd.read_excel(r'data_repaired.xlsx')

# %%
data
# Out:
#                                                     link     price  \
# 0      yeniemlak.az/elan/satilir-3-otaqli-bina-evi-me...  125000.0
# 1      yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   95000.0
# 2      yeniemlak.az/elan/satilir-1-otaqli-bina-ev-men...   53500.0
# 3      yeniemlak.az/elan/satilir-3-otaqli-heyet-evi-v...   46000.0
# 4      yeniemlak.az/elan/satilir-4-otaqli-bina-evi-me...  265000.0
# ...                                                  ...       ...
# 36607  yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   62000.0
# 36608  yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   34000.0
# 36609  yeniemlak.az/elan/satilir-6-sot-torpaq-sahesi-...   24000.0
# 36610  yeniemlak.az/elan/satilir-3-otaqli-bina-evi-me...  189900.0
# 36611  yeniemlak.az/elan/satilir-4-otaqli-heyet-evi-v...   85000.0
#
#        view_counts        date        id  property_category  room_count  area  \
# 0             13.0  11.08.2023  787119.0    Bina evi menzil         NaN   NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36612 entries, 0 to 36611
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   link               36612 non-null  object
#  1   price              36609 non-null  float64
#  2   view_counts        36609 non-null  float64
#  3   date               36609 non-null  object
#  4   id                 36609 non-null  float64
#  5   property_category  36609 non-null  object
#  6   room_count         0 non-null      float64
#  7   area               0 non-null      float64
#  8   doc_type           0 non-null      float64
#  9   flat               0 non-null      float64
#  10  address            0 non-null      float64
#  11  address_2          0 non-null      float64
#  12  description        36609 non-null  object
#  13  check              26088 non-null  object
#  14  owner_number       36609 non-null  object
# ...

# %%
# import pandas as pd



# # Split and stack the phone numbers
# data['owner_number_extracted'] = data['owner_number'].str.split(',')
# data = data.explode('owner_number_extracted', ignore_index=True)

# # Rename the column

# data['owner_number_extracted']
# Out:
# 0        t-0702875314
# 1        t-0558875314
# 2        t-0503380801
# 3        t-0556735384
# 4        t-0703088878
#              ...
# 52117    t-0502044041
# 52118    t-0702044041
# 52119    t-0552360500
# 52120    t-0552006710
# 52121    t-0513113068
# Name: owner_number_extracted, Length: 52122, dtype: object

# %%
data
# Out:
#                                                     link     price  \
# 0      yeniemlak.az/elan/satilir-3-otaqli-bina-evi-me...  125000.0
# 1      yeniemlak.az/elan/satilir-3-otaqli-bina-evi-me...  125000.0
# 2      yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   95000.0
# 3      yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   95000.0
# 4      yeniemlak.az/elan/satilir-1-otaqli-bina-ev-men...   53500.0
# ...                                                  ...       ...
# 52117  yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   34000.0
# 52118  yeniemlak.az/elan/satilir-2-otaqli-bina-evi-me...   34000.0
# 52119  yeniemlak.az/elan/satilir-6-sot-torpaq-sahesi-...   24000.0
# 52120  yeniemlak.az/elan/satilir-3-otaqli-bina-evi-me...  189900.0
# 52121  yeniemlak.az/elan/satilir-4-otaqli-heyet-evi-v...   85000.0
#
#        view_counts        date        id  property_category  room_count  area  \
# 0             13.0  11.08.2023  787119.0    Bina evi menzil         NaN   NaN
# ...

# %%
data.to_excel('data_exploded.xlsx', index=False)
